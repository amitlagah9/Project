# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# df=sns.load_dataset("t")
df = pd.read_csv('t.csv')
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %%
sns.countplot(df,x="age")
plt.title("Number of Teens")
# Out:
# Text(0.5, 1.0, 'Number of Teens')

# %%
sns.histplot(df,x="gender",)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
sns.histplot(df,x="sleep_hours",kde=True)
# Out:
# <Axes: xlabel='sleep_hours', ylabel='Count'>

# %%
sns.barplot(df,x="age",y="daily_social_media_hours",hue="platform_usage")
# Out:
# <Axes: xlabel='age', ylabel='daily_social_media_hours'>

# %%
sns.barplot(df,x="age",y="addiction_level",hue="gender")
# Out:
# <Axes: xlabel='age', ylabel='addiction_level'>

# %%
sns.barplot(df,x="platform_usage",y="daily_social_media_hours",hue="gender")
# Out:
# <Axes: xlabel='platform_usage', ylabel='daily_social_media_hours'>

# %%
sns.lineplot(df,x= "sleep_hours", y = "addiction_level")
# Out:
# <Axes: xlabel='sleep_hours', ylabel='addiction_level'>

# %%
sns.lineplot(df.head(1000),x="age",y="physical_activity")
# Out:
# <Axes: xlabel='age', ylabel='physical_activity'>

# %%
sns.lineplot(df.head(500),x="social_interaction_level",y="platform_usage",hue="gender")
# Out:
# <Axes: xlabel='social_interaction_level', ylabel='platform_usage'>

# %%
plt.pie(df["platform_usage"].value_counts(),labels=df["platform_usage"].value_counts().index,autopct="%1.2f%%")
plt.title("platform usage")
# Out:
# Text(0.5, 1.0, 'platform usage')

# %%
plt.pie(df["social_interaction_level"].value_counts(),labels = df["social_interaction_level"].value_counts().index,autopct = "%1.2f%%")
plt.title("interaction Level")
# Out:
# Text(0.5, 1.0, 'interaction Level')
